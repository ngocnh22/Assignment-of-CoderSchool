# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)
#
# # SF Salaries Exercise
#
# Explore San Francisco city employee salary data.
#
# ## Overview
#
# One way to understand how a city government works is by looking at who it employs and how its employees are compensated. This data contains the names, job title, and compensation for San Francisco city employees on an annual basis from 2011 to 2014.
#
#
#
# Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.
#
# ## Resourses
#
# [Pandas API Reference](https://pandas.pydata.org/pandas-docs/stable/api.html)
#
# [NumPy Reference](https://docs.scipy.org/doc/numpy/reference/)
#
# [Visualization with Seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# **Read `Salaries.csv` as a dataframe called `sal`.**

# %%
link = "https://s3-ap-southeast-1.amazonaws.com/intro-to-ml-minhdh/Salaries.csv"
sal = pd.read_csv(link)

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
sal.head()
# Out:
#    Id       EmployeeName  ...         Agency  Status
# 0   1     NATHANIEL FORD  ...  San Francisco     NaN
# 1   2       GARY JIMENEZ  ...  San Francisco     NaN
# 2   3     ALBERT PARDINI  ...  San Francisco     NaN
# 3   4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4   5    PATRICK GARDNER  ...  San Francisco     NaN
#
# [5 rows x 13 columns]

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**
#
# Keyword: [mean](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html)

# %%
sal.BasePay.mean()
# Out:
# 66325.44884050643

# %% [markdown]
# **What is the lowest and highest amount of BasePay?**
#
# Keyword:
# [min](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.min.html) ,
# [max](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.max.html)

# %%
sal.BasePay.min()
# Out:
# -166.01

# %%
sal.BasePay.max()
# Out:
# 319275.01

# %% [markdown]
# **How about OvertimePay in the dataset? What is the average, lowest, highest amount?**

# %%
sal.groupby('OvertimePay').agg(['mean', 'min', 'max'])
# Out:
#                         Id                        BasePay  ... Notes Status
#                       mean     min     max           mean  ...   max   mean min max
# OvertimePay                                                ...
# -0.01         90715.000000   90715   90715   75033.030000  ...   NaN    NaN NaN NaN
#  0.00         77093.868897       1  148654   59052.468386  ...   NaN    NaN NaN NaN
#  0.02         44426.000000   44426   44426   97435.010000  ...   NaN    NaN NaN NaN
#  0.52         99025.000000   99025   99025   48955.570000  ...   NaN    NaN NaN NaN
#  0.77         33722.000000   33722   33722    3940.530000  ...   NaN    NaN NaN NaN
#  1.34         34987.000000   34987   34987       0.000000  ...   NaN    NaN NaN NaN
#  1.76         82109.000000   82109   82109   95123.030000  ...   NaN    NaN NaN NaN
#  2.42        139523.000000  139523  139523   28820.700000  ...   NaN    NaN NaN NaN
#  2.87         30319.000000   30319   30319    5745.000000  ...   NaN    NaN NaN NaN
#  3.16          7235.000000    7235    7235  103101.460000  ...   NaN    NaN NaN NaN
#  3.19        105115.000000  105115  105115   13335.810000  ...   NaN    NaN NaN NaN
#  3.38          7407.000000    7407    7407  110242.940000  ...   NaN    NaN NaN NaN
#  3.45          6965.000000    6909    7021  112355.810000  ...   NaN    NaN NaN NaN
#  3.48         30447.000000   30447   30447   13226.000000  ...   NaN    NaN NaN NaN
#  3.50         43911.000000   43911   43911  114887.530000  ...   NaN    NaN NaN NaN
#  3.54         72208.000000   72208   72208     622.870000  ...   NaN    NaN NaN NaN
#  3.57         61217.666667   31450  117682   42502.886667  ...   NaN    NaN NaN NaN
#  3.58         79669.000000   79669   79669  123471.010000  ...   NaN    NaN NaN NaN
#  3.78          8012.000000    8012    8012  100154.040000  ...   NaN    NaN NaN NaN
#  4.18         98450.000000   98450   98450   50934.560000  ...   NaN    NaN NaN NaN
#  4.26         30944.000000   30944   30944   12357.630000  ...   NaN    NaN NaN NaN
#  4.31         63717.000000   63717   63717   26324.000000  ...   NaN    NaN NaN NaN
#  4.70         89961.750000   83244  108748   70565.252500  ...   NaN    NaN NaN NaN
#  5.01         88234.000000   88234   88234   80052.000000  ...   NaN    NaN NaN NaN
#  5.20         80998.000000   80998   80998  105436.540000  ...   NaN    NaN NaN NaN
#  5.25         34632.000000   34632   34632    2282.000000  ...   NaN    NaN NaN NaN
#  5.35        106698.000000  104233  109163    9302.415000  ...   NaN    NaN NaN NaN
#  5.55         65024.000000   65024   65024   26098.400000  ...   NaN    NaN NaN NaN
#  5.83        109470.000000  109470  109470    1529.850000  ...   NaN    NaN NaN NaN
#  5.87         83191.000000   83011   83371   94982.860000  ...   NaN    NaN NaN NaN
# ...                    ...     ...     ...            ...  ...   ...    ...  ..  ..
#  126725.82      125.000000     125     125   88062.000000  ...   NaN    NaN NaN NaN
#  126778.88      104.000000     104     104   88400.700000  ...   NaN    NaN NaN NaN
#  127620.50    72989.000000   72989   72989  135144.270000  ...   NaN    NaN NaN NaN
#  127698.35   110609.000000  110609  110609  111640.480000  ...   NaN    NaN NaN NaN
#  128685.99   110540.000000  110540  110540  179464.140000  ...   NaN    NaN NaN NaN
#  129414.28    36366.000000   36366   36366   88062.000000  ...   NaN    NaN NaN NaN
#  130268.39    36239.000000   36239   36239  109783.870000  ...   NaN    NaN NaN NaN
#  131217.63    72928.000000   72928   72928  186236.420000  ...   NaN    NaN NaN NaN
#  132615.09    72974.000000   72974   72974  135144.280000  ...   NaN    NaN NaN NaN
#  133355.19    36313.000000   36313   36313  103226.600000  ...   NaN    NaN NaN NaN
#  133645.42    36207.000000   36207   36207  128091.780000  ...   NaN    NaN NaN NaN
#  134077.58   110594.000000  110594  110594  112703.730000  ...   NaN    NaN NaN NaN
#  135159.38       89.000000      89      89   88062.000000  ...   NaN    NaN NaN NaN
#  136843.65    73019.000000   73019   73019  109390.440000  ...   NaN    NaN NaN NaN
#  137462.80    36348.000000   36348   36348   88400.700000  ...   NaN    NaN NaN NaN
#  139102.95       36.000000      36      36  101953.200000  ...   NaN    NaN NaN NaN
#  139260.09    36222.000000   36222   36222  110847.130000  ...   NaN    NaN NaN NaN
#  145867.35   110583.000000  110583  110583  111640.490000  ...   NaN    NaN NaN NaN
#  146415.32    36162.000000   36162   36162  111921.000000  ...   NaN    NaN NaN NaN
#  148147.92   110653.000000  110653  110653   93475.610000  ...   NaN    NaN NaN NaN
#  156077.49    73022.000000   73022   73022   95123.080000  ...   NaN    NaN NaN NaN
#  160418.47    36200.000000   36200   36200  109783.860000  ...   NaN    NaN NaN NaN
#  163477.81    72944.000000   72944   72944  135903.020000  ...   NaN    NaN NaN NaN
#  169659.92   110584.000000  110584  110584   94191.000000  ...   NaN    NaN NaN NaN
#  173178.23   110578.000000  110578  110578   94191.130000  ...   NaN    NaN NaN NaN
#  173547.73   110575.000000  110575  110575   94191.040000  ...   NaN    NaN NaN NaN
#  192424.49    36164.000000   36164   36164  126863.190000  ...   NaN    NaN NaN NaN
#  196689.18    72965.000000   72965   72965   95123.000000  ...   NaN    NaN NaN NaN
#  220909.48    36160.000000   36160   36160  128808.870000  ...   NaN    NaN NaN NaN
#  245131.88        2.000000       2       2  155966.020000  ...   NaN    NaN NaN NaN
#
# [65998 rows x 27 columns]

# %% [markdown]
# **What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).**

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']

# %%
# Now try to select Employees who have name "GARY JIMENEZ"
# Your code here
sal[sal.EmployeeName == 'GARY JIMENEZ'].JobTitle
# Out:
# 1    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)?**
#
# ---

# %%
sal[sal.EmployeeName == 'JOSEPH DRISCOLL'].TotalPayBenefits
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ## **What is the name of highest paid person (including benefits)?**

# %%
sal[sal.TotalPayBenefits == sal.TotalPayBenefits.max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %% [markdown]
# **What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal[sal.TotalPay == sal.TotalPay.min()]
# Out:
#             Id EmployeeName  ...         Agency  Status
# 148653  148654    Joe Lopez  ...  San Francisco     NaN
#
# [1 rows x 13 columns]

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year? (2011-2014) ?**
# Keyword: _groupby_

# %%
sal.groupby(by='Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# **How many unique job titles are there?**
#
# Keyword: _unique, nunique_

# %%
sal.JobTitle.nunique()
# Out:
# 2159

# %% [markdown]
# **What are the top 5 most common jobs?**
#
# Keyword: *value_counts*

# %%
sal_job = sal.groupby(by='JobTitle').nunique()
common_job = sal_job.sort_values(by='Id', ascending=False)['Id']
common_job.head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: Id, dtype: int64

# %% [markdown]
# **How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)**

# %%
sal_job[sal_job['Id'] == 1].size
# Out:
# 3107

# %% [markdown]
# **How many people have the word Chief in their job title?**

# %%
sal[sal['JobTitle'].str.contains(pat='chief', case=False)].shape[0]
# Out:
# 627

# %% [markdown]
# ## Data Visualization
#
# **Implement seaborn's countplot with x='Year'**

# %%
sns.countplot(x='Year', data=sal);

# %% [markdown]
# **Implement seaborn's distplot for BasePay of Year 2011**

# %%
sns.distplot(sal[sal['Year'] == 2011]['BasePay'], bins=25, axlabel='BasePay of Year 2011');

# %% [markdown]
# **How about other Year**

# %%
import matplotlib.pyplot as plt

# %%
year = sal['Year'].unique()
n_years = len(year)

f, axes = plt.subplots(1, n_years, figsize=(30, 5))
f.suptitle('Distribution of Base pay over the period 2011 - 2014')

for i in range(n_years):
    sns.distplot(sal[sal['Year'] == year[i]]['BasePay'].dropna(), bins=25, ax=axes[i], axlabel=str(year[i]));

# %% [markdown]
# ## Bonus
#
# **Visualize top 5 Jobs with BasePay, Benefits and OvertimePay**
#
# Keyword: *index, isin, groupby, mean, plot*

# %%
labels = common_job.index
common_job_sal = sal[sal['JobTitle'].isin(labels)].groupby(by=['JobTitle']).mean()[['BasePay', 'Benefits', 'OvertimePay']]

# %%
common_job_sal.plot(y=['BasePay', 'Benefits', 'OvertimePay'], kind='bar');

# %% [markdown]
# **Fun Fact: Is there a correlation between length of the Job Title string and Salary?**
#
# *Hint: corr()*

# %%
sal['JobTitleLen'] = sal['JobTitle'].str.len()
sub_sal = sal[['JobTitleLen', 'BasePay', 'OvertimePay', 'TotalPayBenefits']]
sub_sal.head()
# Out:
#    JobTitleLen    BasePay  OvertimePay  TotalPayBenefits
# 0           46  167411.18         0.00         567595.43
# 1           31  155966.02    245131.88         538909.28
# 2           31  212739.13    106088.18         335279.91
# 3           36   77916.00     56120.71         332343.61
# 4           44  134401.60      9737.00         326373.19

# %%
sns.heatmap(sub_sal.corr(), annot=True, cmap='Blues');

# %% [markdown]
# # Great Job!
